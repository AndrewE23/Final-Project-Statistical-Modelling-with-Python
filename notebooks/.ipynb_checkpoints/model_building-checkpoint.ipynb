# %%
# libraries
import numpy as np
import pandas as pd
import statsmodels.api as sm

# %%
# Load CSV file:
station_pois = pd.read_csv('../data/collective_stations_data.csv')

# Generate one more column for analysis:
station_pois['fsq_poi_counts'] = station_pois['park_poi_counts'] + station_pois['bar_poi_counts'] + station_pois['food_poi_counts'] + station_pois['grocer_poi_counts']

# Create .csv and show final DataFrame:

station_pois.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 144 non-null    object
#  1   latitude           144 non-null    float64
#  2   longitude          144 non-null    float64
#  3   name               144 non-null    object
#  4   est_bike_slots     144 non-null    int64
#  5   park_poi_counts    144 non-null    int64
#  6   bar_poi_counts     144 non-null    int64
#  7   food_poi_counts    144 non-null    int64
#  8   grocer_poi_counts  144 non-null    int64
#  9   yelp_counts        144 non-null    int64
#  10  fsq_poi_counts     144 non-null    int64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 12.5+ KB

# %%
station_pois.describe()
# Out:
#          latitude   longitude  est_bike_slots  park_poi_counts  \
# count  144.000000  144.000000      144.000000       144.000000
# mean    43.257392  -79.875175       12.055556         6.055556
# std      0.007420    0.032363        5.515113         4.384936
# min     43.242163  -79.953754        1.000000         0.000000
# 25%     43.252003  -79.895209        9.000000         2.000000
# 50%     43.256647  -79.869532       11.000000         6.000000
# 75%     43.262017  -79.855642       13.000000         9.000000
# max     43.289479  -79.766388       34.000000        15.000000
#
#        bar_poi_counts  food_poi_counts  grocer_poi_counts  yelp_counts  \
# count      144.000000       144.000000         144.000000   144.000000
# mean        15.763889        27.916667           8.631944    39.736111
# std         11.358116         6.101129           7.708633    12.613671
# min          0.000000         0.000000           0.000000     0.000000
# 25%          5.000000        30.000000           3.000000    32.000000
# 50%         13.000000        30.000000           6.000000    44.000000
# 75%         30.000000        30.000000          13.000000    50.000000
# max         30.000000        30.000000          26.000000    50.000000
#
#        fsq_poi_counts
# count      144.000000
# mean        58.368056
# std         24.708580
# min          1.000000
# 25%         39.000000
# 50%         53.000000
# 75%         82.250000
# max         98.000000

# %% [markdown]
# #### Notes: 'est_bike_slots' is my singular dependent variable; all others are potential independent variables I can test it against.

# %% [markdown]
# Build a regression model.

# %% [markdown]
# I decided to employ backward selection method for refining my model:

# %%
# Dependent Variable = est_bike_slots; also dropping coordinates, id, and names from test
y = station_pois['est_bike_slots']
indep = station_pois.drop(columns = ['latitude', 'longitude', 'name', 'id', 'yelp_counts', 'fsq_poi_counts', 'est_bike_slots'])

X = [sm.add_constant(indep[column]) for column in indep.columns] 
#Print all the X columns in a formatted manner as pandas dataframe
df_X = pd.DataFrame(indep, columns=indep.columns)
X
# Out:
# [     const  park_poi_counts
#  0      1.0                8
#  1      1.0                5
#  2      1.0                6
#  3      1.0                8
#  4      1.0                8
#  ..     ...              ...
#  139    1.0                7
#  140    1.0                8
#  141    1.0                1
#  142    1.0                1
#  143    1.0               10
#
#  [144 rows x 2 columns],
#       const  bar_poi_counts
#  0      1.0              30
#  1      1.0              11
#  2      1.0              17
#  3      1.0              30
#  4      1.0              30
#  ..     ...             ...
#  139    1.0              19
#  140    1.0              30
#  141    1.0               3
#  142    1.0               1
#  143    1.0              30
#
#  [144 rows x 2 columns],
#       const  food_poi_counts
#  0      1.0               30
#  1      1.0               30
#  2      1.0               30
#  3      1.0               30
#  4      1.0               30
#  ..     ...              ...
#  139    1.0               30
#  140    1.0               30
#  141    1.0               30
#  142    1.0                5
#  143    1.0               30
#
#  [144 rows x 2 columns],
#       const  grocer_poi_counts
#  0      1.0                 24
#  1      1.0                  5
#  2      1.0                 12
#  3      1.0                 20
#  4      1.0                 24
#  ..     ...                ...
#  139    1.0                  2
#  140    1.0                 20
#  141    1.0                  4
#  142    1.0                  0
#  143    1.0                 23
#
#  [144 rows x 2 columns]]

# %%
# Models:
models = [sm.OLS(y,x) for x in X]
results = [model.fit() for model in models]

# Significance Values:
adj_rsquared = [results.rsquared_adj for results in results]
pval = [results.pvalues for results in results]

Params = [results.params for results in results]
print(results[0].summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         est_bike_slots   R-squared:                       0.049
# Model:                            OLS   Adj. R-squared:                  0.043
# Method:                 Least Squares   F-statistic:                     7.376
# Date:                Mon, 05 Jun 2023   Prob (F-statistic):            0.00743
# Time:                        04:58:33   Log-Likelihood:                -446.06
# No. Observations:                 144   AIC:                             896.1
# Df Residuals:                     142   BIC:                             902.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const              13.7480      0.768     17.890      0.000      12.229      15.267
# park_poi_counts    -0.2795      0.103     -2.716      0.007      -0.483      -0.076
# ==============================================================================
# Omnibus:                       57.061   Durbin-Watson:                   1.791
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              142.575
# Skew:                           1.650   Prob(JB):                     1.10e-31
# Kurtosis:                       6.587   Cond. No.                         12.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#Model Output
for i in range(len(indep.columns)):
    print("Model for", indep.columns[i])
    print(Results[i].summary())
    print(" ")  #print a blank line

#Create a dataframe with the indep. variables, their adj. R-squared, p-values and params
df = pd.DataFrame({'Indep. Variables': indep.columns, 'Adj. R-squared': Adj_Rsquared, 'P-values': Pval, 'Params': Params})
df

#Sort the dataframe by the adj. R-squared
df.sort_values(by='Adj. R-squared', ascending=False)
# Out:
# Model for park_poi_counts
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         est_bike_slots   R-squared:                       0.049
# Model:                            OLS   Adj. R-squared:                  0.043
# Method:                 Least Squares   F-statistic:                     7.376
# Date:                Mon, 05 Jun 2023   Prob (F-statistic):            0.00743
# Time:                        04:59:21   Log-Likelihood:                -446.06
# No. Observations:                 144   AIC:                             896.1
# Df Residuals:                     142   BIC:                             902.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const              13.7480      0.768     17.890      0.000      12.229      15.267
# park_poi_counts    -0.2795      0.103     -2.716      0.007      -0.483      -0.076
# ==============================================================================
# Omnibus:                       57.061   Durbin-Watson:                   1.791
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              142.575
# Skew:                           1.650   Prob(JB):                     1.10e-31
# Kurtosis:                       6.587   Cond. No.                         12.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Model for bar_poi_counts
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         est_bike_slots   R-squared:                       0.048
# Model:                            OLS   Adj. R-squared:                  0.041
# Method:                 Least Squares   F-statistic:                     7.156
# Date:                Mon, 05 Jun 2023   Prob (F-statistic):            0.00835
# Time:                        04:59:21   Log-Likelihood:                -446.16
# No. Observations:                 144   AIC:                             896.3
# Df Residuals:                     142   BIC:                             902.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             13.7322      0.772     17.798      0.000      12.207      15.257
# bar_poi_counts    -0.1064      0.040     -2.675      0.008      -0.185      -0.028
# ==============================================================================
# Omnibus:                       57.502   Durbin-Watson:                   1.786
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              146.323
# Skew:                           1.653   Prob(JB):                     1.68e-32
# Kurtosis:                       6.668   Cond. No.                         33.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Model for food_poi_counts
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         est_bike_slots   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.124
# Date:                Mon, 05 Jun 2023   Prob (F-statistic):              0.291
# Time:                        04:59:21   Log-Likelihood:                -449.14
# No. Observations:                 144   AIC:                             902.3
# Df Residuals:                     142   BIC:                             908.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const              14.2915      2.159      6.620      0.000      10.024      18.559
# food_poi_counts    -0.0801      0.076     -1.060      0.291      -0.229       0.069
# ==============================================================================
# Omnibus:                       65.841   Durbin-Watson:                   1.785
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              189.153
# Skew:                           1.855   Prob(JB):                     8.43e-42
# Kurtosis:                       7.214   Cond. No.                         134.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Model for grocer_poi_counts
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         est_bike_slots   R-squared:                       0.034
# Model:                            OLS   Adj. R-squared:                  0.028
# Method:                 Least Squares   F-statistic:                     5.063
# Date:                Mon, 05 Jun 2023   Prob (F-statistic):             0.0260
# Time:                        04:59:21   Log-Likelihood:                -447.18
# No. Observations:                 144   AIC:                             898.4
# Df Residuals:                     142   BIC:                             904.3
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                13.2015      0.682     19.365      0.000      11.854      14.549
# grocer_poi_counts    -0.1328      0.059     -2.250      0.026      -0.249      -0.016
# ==============================================================================
# Omnibus:                       58.453   Durbin-Watson:                   1.773
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              145.947
# Skew:                           1.698   Prob(JB):                     2.03e-32
# Kurtosis:                       6.576   Cond. No.                         17.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#     Indep. Variables  Adj. R-squared  \
# 0    park_poi_counts        0.042682
# 1     bar_poi_counts        0.041275
# 3  grocer_poi_counts        0.027629
# 2    food_poi_counts        0.000864
#
#                                             P-values  \
# 0  const              3.333134e-38
# park_poi_count...
# 1  const             5.545314e-38
# bar_poi_counts ...
# 3  const                1.115738e-41
# grocer_poi_c...
# 2  const              6.846666e-10
# food_poi_count...
#
#                                               Params
# 0  const              13.747959
# park_poi_counts  ...
# 1  const             13.732190
# bar_poi_counts    ...
# 3  const                13.201460
# grocer_poi_coun...
# 2  const              14.291476
# food_poi_counts  ...

# %%
for i in range(len(Adj_Rsquared)):
     print(f'adj_R2: {Adj_Rsquared[i]:.3f}, P-values: {*Pval[i],}, column: {indep.columns[i]}')
# Out:
# adj_R2: 0.043, P-values: (3.3331344037826663e-38, 0.007432857518816909), column: park_poi_counts
# adj_R2: 0.041, P-values: (5.545314131761724e-38, 0.008346936600383714), column: bar_poi_counts
# adj_R2: 0.001, P-values: (6.846665594717721e-10, 0.2909460691789762), column: food_poi_counts
# adj_R2: 0.028, P-values: (1.1157382527248846e-41, 0.02597570031087397), column: grocer_poi_counts

# %%
# park_poi_counts has the highest adj_r2, so we can proceed with the model
remaining_var = indep.drop(['park_poi_counts'], axis=1)
remaining_var.head()
# Out:
#    bar_poi_counts  food_poi_counts  grocer_poi_counts
# 0              30               30                 24
# 1              11               30                  5
# 2              17               30                 12
# 3              30               30                 20
# 4              30               30                 24

# %%
included_df = indep[['park_poi_counts']]
included_df
# Out:
#      park_poi_counts
# 0                  8
# 1                  5
# 2                  6
# 3                  8
# 4                  8
# ..               ...
# 139                7
# 140                8
# 141                1
# 142                1
# 143               10
#
# [144 rows x 1 columns]

# %%
X = [sm.add_constant(pd.merge(included_df,remaining_var[column], right_index = True, left_index = True)) for column in remaining_var.columns] 
X[0]
# Out:
#      const  park_poi_counts  bar_poi_counts
# 0      1.0                8              30
# 1      1.0                5              11
# 2      1.0                6              17
# 3      1.0                8              30
# 4      1.0                8              30
# ..     ...              ...             ...
# 139    1.0                7              19
# 140    1.0                8              30
# 141    1.0                1               3
# 142    1.0                1               1
# 143    1.0               10              30
#
# [144 rows x 3 columns]

# %%
models = [sm.OLS(y,x) for x in X]
Results = [model.fit() for model in models]
Adj_Rsquared = [results.rsquared_adj for results in Results]
Pval = [results.pvalues for results in Results] 

for i in range(len(Adj_Rsquared)):
     print(f'adj_R2: {Adj_Rsquared[i]:.3f}, P-values: {*Pval[i],}, column: {remaining_var.columns[i]}')
# Out:
# adj_R2: 0.041, P-values: (5.1404824511215365e-37, 0.33521789040586814, 0.39538276072492473), column: bar_poi_counts
# adj_R2: 0.037, P-values: (1.4931262870336451e-10, 0.012525798976562669, 0.6332875975957615), column: food_poi_counts
# adj_R2: 0.039, P-values: (1.2256882353321797e-37, 0.10318867531434955, 0.49596226900604046), column: grocer_poi_counts

# %% [markdown]
# Provide model output and an interpretation of the results.

# %% [markdown]
# My hypothesis (that bike station placement correlates with specific POI density) is wrong, and my model is unable to disprove the null hypothesis that it is not. My P-values are not decreasing, my R-Squares are staying relatively consistent, and none of the other metrics for testing significance have turned any meaningful results. This at least suggests there is no positive correlation between bike station placement and what kinds of venues are in the immediate area. It is entirely possible that there is some other criteria I have overlooked, however.
#
# My last output is shared below:

# %%
#Model Output
for i in range(len(remaining_var.columns)):
    print("Model for", remaining_var.columns[i])
    print(results[i].summary())
    print(" ")  #print a blank line

#Create a dataframe with the indep. variables, their adj. R-squared, p-values and params
df = pd.DataFrame({'Indep. Variables': remaining_var.columns, 'Adj. R-squared': Adj_Rsquared, 'P-values': Pval, 'Params': Params})
df

#Sort the dataframe by the adj. R-squared
df.sort_values(by='Adj. R-squared', ascending=False)
# Out:
# Model for bar_poi_counts
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         est_bike_slots   R-squared:                       0.054
# Model:                            OLS   Adj. R-squared:                  0.041
# Method:                 Least Squares   F-statistic:                     4.044
# Date:                Mon, 05 Jun 2023   Prob (F-statistic):             0.0196
# Time:                        05:20:14   Log-Likelihood:                -445.69
# No. Observations:                 144   AIC:                             897.4
# Df Residuals:                     141   BIC:                             906.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const              13.9319      0.799     17.439      0.000      12.353      15.511
# park_poi_counts    -0.1643      0.170     -0.967      0.335      -0.500       0.172
# bar_poi_counts     -0.0559      0.066     -0.852      0.395      -0.186       0.074
# ==============================================================================
# Omnibus:                       56.314   Durbin-Watson:                   1.784
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              139.882
# Skew:                           1.629   Prob(JB):                     4.22e-31
# Kurtosis:                       6.563   Cond. No.                         36.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Model for food_poi_counts
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         est_bike_slots   R-squared:                       0.051
# Model:                            OLS   Adj. R-squared:                  0.037
# Method:                 Least Squares   F-statistic:                     3.782
# Date:                Mon, 05 Jun 2023   Prob (F-statistic):             0.0251
# Time:                        05:20:14   Log-Likelihood:                -445.94
# No. Observations:                 144   AIC:                             897.9
# Df Residuals:                     141   BIC:                             906.8
# Df Model:                           2
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const              14.6948      2.125      6.916      0.000      10.494      18.896
# park_poi_counts    -0.2680      0.106     -2.529      0.013      -0.477      -0.059
# food_poi_counts    -0.0364      0.076     -0.478      0.633      -0.187       0.114
# ==============================================================================
# Omnibus:                       57.953   Durbin-Watson:                   1.778
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              146.810
# Skew:                           1.671   Prob(JB):                     1.32e-32
# Kurtosis:                       6.646   Cond. No.                         138.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Model for grocer_poi_counts
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         est_bike_slots   R-squared:                       0.053
# Model:                            OLS   Adj. R-squared:                  0.039
# Method:                 Least Squares   F-statistic:                     3.907
# Date:                Mon, 05 Jun 2023   Prob (F-statistic):             0.0223
# Time:                        05:20:14   Log-Likelihood:                -445.82
# No. Observations:                 144   AIC:                             897.6
# Df Residuals:                     141   BIC:                             906.6
# Df Model:                           2
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                13.8418      0.782     17.698      0.000      12.296      15.388
# park_poi_counts      -0.2206      0.134     -1.640      0.103      -0.486       0.045
# grocer_poi_counts    -0.0522      0.076     -0.683      0.496      -0.203       0.099
# ==============================================================================
# Omnibus:                       56.309   Durbin-Watson:                   1.779
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              137.845
# Skew:                           1.639   Prob(JB):                     1.17e-30
# Kurtosis:                       6.498   Cond. No.                         23.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[150], line 8
#       5     print(" ")  #print a blank line
#       7 #Create a dataframe with the indep. variables, their adj. R-squared, p-values and params
# ----> 8 df = pd.DataFrame({'Indep. Variables': remaining_var.columns, 'Adj. R-squared': Adj_Rsquared, 'P-values': Pval, 'Params': Params})
#       9 df
#      11 #Sort the dataframe by the adj. R-squared
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:664, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     658     mgr = self._init_mgr(
#     659         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     660     )
#     662 elif isinstance(data, dict):
#     663     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 664     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     665 elif isinstance(data, ma.MaskedArray):
#     666     import numpy.ma.mrecords as mrecords
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py:493, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     489     else:
#     490         # dtype check to exclude e.g. range objects, scalars
#     491         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 493 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py:118, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     115 if verify_integrity:
#     116     # figure out the index, if necessary
#     117     if index is None:
# --> 118         index = _extract_index(arrays)
#     119     else:
#     120         index = ensure_index(index)
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py:666, in _extract_index(data)
#     664 lengths = list(set(raw_lengths))
#     665 if len(lengths) > 1:
# --> 666     raise ValueError("All arrays must be of the same length")
#     668 if have_dicts:
#     669     raise ValueError(
#     670         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     671     )
#
# ValueError: All arrays must be of the same length

# %% [markdown]
# # Stretch

# %% [markdown]
# How can you turn the regression model into a classification model?
